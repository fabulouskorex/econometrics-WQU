# %% [markdown]
# # 1. Data Importing

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %%
GLD_ETF_df = pd.read_csv("SPDR Gold Shares (GLD) Jan - Dec 2020.csv",parse_dates=True,index_col=0)
EQT_ETF_df = pd.read_csv("Amundi CAC 40 UCITS ETF-C (C40.PA) Jan 2020 - Dec 2020.csv",parse_dates=True,index_col=0)
BTC_df = pd.read_csv("Bitcoin USD (BTC-USD) Jan 2020 - Dec 2020.csv",parse_dates=True,index_col=0)

# %%
gold_ETF_df = pd.read_csv("SPDR Gold Shares (GLD) April 2020 - December 2020.csv",parse_dates=True,index_col=0)
equity_ETF_df = pd.read_csv("Amundi CAC 40 UCITS ETF-C (C40.PA) April 2020 - December 2020.csv",parse_dates=True,index_col=0)
bitcoin_df = pd.read_csv("Bitcoin USD (BTC-USD) April 2020 - December 2020.csv",parse_dates=True,index_col=0)

# %% [markdown]
# # 2. Data Processing

# %%
gold_ETF_df['Daily_return_pct'] = gold_ETF_df['Close'].pct_change(1)
gold_ETF_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-04-01  148.199997  150.080002  147.850006  149.449997  149.449997
# 2020-04-02  151.199997  152.500000  150.699997  151.899994  151.899994
# 2020-04-03  152.229996  153.089996  151.660004  152.649994  152.649994
# 2020-04-06  154.160004  157.220001  153.960007  156.880005  156.880005
# 2020-04-07  155.330002  156.139999  154.380005  156.039993  156.039993
#
#               Volume  Daily_return_pct
# Date
# 2020-04-01  11827400               NaN
# 2020-04-02   9188300          0.016393
# 2020-04-03   8469100          0.004937
# 2020-04-06  14739300          0.027711
# 2020-04-07   9195400         -0.005354

# %%
equity_ETF_df['Daily_return_pct'] = equity_ETF_df['Close'].pct_change(1)
equity_ETF_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2020-04-01  62.340000  62.490002  61.330002  61.520000  61.520000      0.0
# 2020-04-02  61.720001  62.720001  61.599998  62.090000  62.090000      0.0
# 2020-04-03  61.910000  62.099998  61.570000  61.889999  61.889999      0.0
# 2020-04-06  63.500000  64.500000  63.250000  64.500000  64.500000  40092.0
# 2020-04-07  65.470001  66.650002  65.470001  66.360001  66.360001      0.0
#
#             Daily_return_pct
# Date
# 2020-04-01               NaN
# 2020-04-02          0.009265
# 2020-04-03         -0.003221
# 2020-04-06          0.042172
# 2020-04-07          0.028837

# %%
bitcoin_df['Daily_return_pct'] = bitcoin_df['Close'].pct_change(1)
bitcoin_df.head
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 
# # 4. Graphing

# %%
x=GLD_ETF_df["Close"]["2020-03-01":"2020-12-31"]
moving_avg = x.rolling(20).mean()

plt.figure(figsize=(10,7))
plt.plot(x)
plt.plot(moving_avg)
plt.show()

# %%
x=EQT_ETF_df["Close"]["2020-03-01":"2020-12-31"]
moving_avg = x.rolling(20).mean()

plt.figure(figsize=(10,5))
plt.plot(x)
plt.plot(moving_avg)
plt.show()

# %%
x=BTC_df["Close"]["2020-03-01":"2020-12-31"]
moving_avg = x.rolling(20).mean()

plt.figure(figsize=(10,5))
plt.plot(x, label="BTC_df")
plt.plot(moving_avg, label="moving_avg")
plt.legend()
plt.show()

# %% [markdown]
# # 4.2

# %%
y1_data = gold_ETF_df["Close"]
y2_data = equity_ETF_df["Close"]
fig, y1_axis = plt.subplots()
plt.figure(figsize=(10,5))

y1_color = 'tab:red'
y2_color = 'tab:blue'

y1_axis.set_xlabel('Date')
y1_axis.set_ylabel('gold_ETF_df', color=y1_color)
y1_axis.plot( y1_data, color=y1_color)
y1_axis.tick_params(axis='y', labelcolor=y1_color)
y2_axis = y1_axis.twinx() 


y2_axis.set_ylabel('equity_ETF_df', color=y2_color)  
y2_axis.plot( y2_data, color=y2_color)
y2_axis.tick_params(axis='y', labelcolor=y2_color)

fig.tight_layout()  
plt.show()

# %% [markdown]
# # 4.3

# %%
y1_data = gold_ETF_df["Close"]
y2_data = bitcoin_df["Close"]
fig, y1_axis = plt.subplots()
plt.figure(figsize=(10,5))

y1_color = 'tab:red'
y2_color = 'tab:blue'

y1_axis.set_xlabel('Date')
y1_axis.set_ylabel('gold_ETF_df', color=y1_color)
y1_axis.plot( y1_data, color=y1_color)
y1_axis.tick_params(axis='y', labelcolor=y1_color)
y2_axis = y1_axis.twinx()  


y2_axis.set_ylabel('bitcoin_df', color=y2_color)  
y2_axis.plot( y2_data, color=y2_color)
y2_axis.tick_params(axis='y', labelcolor=y2_color)

fig.tight_layout()  
plt.show()

# %% [markdown]
# # 4.4

# %%
y1_data = equity_ETF_df["Close"]
y2_data = bitcoin_df["Close"]
fig, y1_axis = plt.subplots()
plt.figure(figsize=(10,5))

y1_color = 'tab:red'
y2_color = 'tab:blue'

y1_axis.set_xlabel('Date')
y1_axis.set_ylabel('equity_ETF_df', color=y1_color)
y1_axis.plot( y1_data, color=y1_color)
y1_axis.tick_params(axis='y', labelcolor=y1_color)
y2_axis = y1_axis.twinx()  


y2_axis.set_ylabel('bitcoin_df', color=y2_color)  
y2_axis.plot( y2_data, color=y2_color)
y2_axis.tick_params(axis='y', labelcolor=y2_color)

fig.tight_layout() 
plt.show()
